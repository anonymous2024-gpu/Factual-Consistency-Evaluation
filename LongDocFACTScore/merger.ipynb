# %%
# import pandas as pd

# df1 = pd.read_json("cnndm_gpt35_zero.jsonl", lines=True)
# df1 = df1.rename(columns={"output": "gpt35_summary"})

# df2 = pd.read_json("cnndm_gpt4omini_zero.jsonl", lines=True)
# df2 = df2.rename(columns={"output": "gpt4omini_summary"})

# df3 = pd.read_json("cnndm_llama2_zero.jsonl", lines=True)
# df3 = df3.rename(columns={"output": "llama2_summary"})
# df3.head()

# %%
import pandas as pd
import os

# Define a function to process a JSONL file
def load_and_rename_auto(file_path):
    # Extract the base name of the file (without extension)
    file_name = os.path.basename(file_path)
    
    # Extract the model name (e.g., gpt35, gpt4omini, llama2)
    model_name = file_name.split("_")[1]
    
    # Create the new column name
    new_column_name = f"{model_name}_summary"
    
    # Load the file and rename the 'output' column
    df = pd.read_json(file_path, lines=True)
    return df.rename(columns={"output": new_column_name})

# List of JSONL files to process
file_paths = [
    "cnndm_gpt35_cot.jsonl",
    "cnndm_gpt4omini_cot.jsonl",
    "cnndm_llama2_cot.jsonl",
    "cnndm_llama31_cot.jsonl",
    "cnndm_llama32_cot.jsonl",
    "cnndm_mistral_cot.jsonl",
    "cnndm_orca_cot.jsonl",
    "cnndm_phi35_cot.jsonl",
    "cnndm_vicuna_cot.jsonl",
    
]

dataframes = [load_and_rename_auto(file) for file in file_paths]

# Merge DataFrames on the 'title' column iteratively
merged_df = dataframes[0]
for df in dataframes[1:]:
    merged_df = pd.merge(merged_df, df, on="topic", how="inner")

# Load the CSV file with 'article' and 'highlights' as summary
csv_file_path = r"D:\FActScore-main2\FActScore-main\GenData\CNNDM\summarization_llama2_results.csv"
csv_df = pd.read_csv(csv_file_path)

# Rename 'highlights' to 'summary'
csv_df = csv_df.rename(columns={"highlights": "summary"})

# Merge the CSV file with merged_df based on matching 'title' and 'id'
final_df = pd.merge(merged_df, csv_df[['id', 'article', 'summary']], left_on="topic", right_on="id", how="inner")

# Display the final merged DataFrame
final_df
# Out:
#                                       topic  \
# 0  f001ec5c4704938247d27a44948eebb37ae98d01
# 1  230c522854991d053fe98a718b1defa077a8efef
# 2  4495ba8f3a340d97a9df1476f8a35502bcce1f69
# 3  a38e72fed88684ec8d60dd5856282e999dc8c0ca
# 4  c27cf1b136cc270023de959e7ab24638021bc43f
# 5  1b2cc634e2bfc6f2595260e7ed9b42f77ecbb0ce
# 6  e2706dce6cf26bc61b082438188fdb6e130d9e40
# 7  0d3c8c276d079c4c225f034c69aa024cdab7869d
# 8  6222f33c2c79b80be437335eeb3f488509e92cf5
# 9  2bd8ada1de6a7b02f59430cc82045eb8d29cf033
#
#                                        gpt35_summary  \
# 0  The Palestinian Authority became the 123rd mem...
# 1  A stray dog in Washington State named Theia su...
# 2  Iranian Foreign Minister Mohammad Javad Zarif ...
# 3  Five Americans who were exposed to Ebola in We...
# 4  A Duke student admitted to hanging a noose fro...
# 5  High school basketball star Trey Moses asked f...
# 6  Amnesty International's annual report on the d...
# 7  Andrew Getty, one of the heirs to the Getty oi...
# 8  Tropical storm Maysak, now known as Chedeng, i...
# 9  Bob Barker, the former host of "The Price Is R...
#
#                                    gpt4omini_summary  \
# 0  **Step 1: Identify the key points of the artic...
# 1  **Step 1: Identify the key points of the artic...
# 2  **Step 1: Identify the key points of the artic...
# 3  **Step 1: Identify the key points of the artic...
# 4  **Step 1: Identify the key points of the artic...
# 5  **Step 1: Identify the key points of the artic...
# 6  ### Step 1: Identify the key points of the art...
# 7  **Step 1: Identify the key points of the artic...
# 8  **Step 1: Identify the key points of the artic...
# 9  **Step 1: Identify the key points of the artic...
#
#                                       llama2_summary  \
# 0  to seek it," she added.\n\n\nStep 1: The Pales...
# 1  die and then be found alive. In 2017, a cat in...
# 2  of 1979.\n\nStep 1: Identify the main topic of...
# 3  Five Americans who were exposed to Ebola in We...
# 4  * A Duke student was caught hanging a noose ma...
# 5  good about Trey's decision. "It's a great thin...
# 6  of executions in some countries, including Ira...
# 7  spike and that the stress of a confrontation c...
# 8  cohesive summary.\n\n                Step 3: P...
# 9  Bob Barker, the former host of "The Price Is R...
#
#                                      llama31_summary  \
# 0  The Palestinian Authority officially became th...
# 1  A stray dog in Washington State, now named The...
# 2  Mohammad Javad Zarif, the Iranian foreign mini...
# 3  Five American clinicians for Partners in Healt...
# 4  A noose made of rope was hung from a tree near...
# 5  Trey Moses, a star basketball player from Loui...
# 6  Amnesty International's annual report on the d...
# 7  Andrew Getty, 47, grandson of oil tycoon J. Pa...
# 8  The article reports that a tropical storm, for...
# 9  Bob Barker returned to hosting "The Price Is R...
#
#                                      llama32_summary  \
# 0  The Palestinian Authority has officially joine...
# 1  A stray dog, a one-year-old bully breed mix, w...
# 2  Mohammad Javad Zarif, the Iranian Foreign Mini...
# 3  Five American clinicians from Partners in Heal...
# 4  A Duke University student admitted to placing ...
# 5  A high school basketball player, Trey Moses, a...
# 6  Amnesty International's annual report on the d...
# 7  Andrew Getty, 47, a grandson of oil tycoon J. ...
# 8  The Philippine National Weather Service has wa...
# 9  The TV game show "The Price Is Right" featured...
#
#                                      mistral_summary  \
# 0  The Palestinian Authority officially joined th...
# 1  A stray dog named Theia in Washington State su...
# 2  Mohammad Javad Zarif, the Iranian foreign mini...
# 3  Five healthcare workers from Partners in Healt...
# 4  A Duke University student has admitted to hang...
# 5  Trey Moses, a high school basketball star and ...
# 6  Amnesty International's annual report on the d...
# 7  Andrew Getty, a billionaire heir to the oil fo...
# 8  Tropical Storm Maysak, previously a super typh...
# 9  Bob Barker, the longtime host of "The Price Is...
#
#                                         orca_summary  \
# 0  The Palestinian Authority officially became th...
# 1  A stray dog in Washington State, who was hit b...
# 2  The article discusses lesser-known facts about...
# 3  Five Americans who were exposed to Ebola in We...
# 4  A Duke University student has admitted to hang...
# 5  Trey Moses, a college basketball recruit, aske...
# 6  Amnesty International's annual report on the d...
# 7  Andrew Getty, grandson of oil tycoon J. Paul G...
# 8  Tropical storm Maysak, also known as Chedeng, ...
# 9  Bob Barker, former host of "The Price Is Right...
#
#                                        phi35_summary  \
# 0  Step 1: Key Points\n- The Palestinian Authorit...
# 1  Step 1: Key Points\n- A stray dog in Washingto...
# 2  The article discusses Iranian Foreign Minister...
# 3  Step 1: Identify the key points of the article...
# 4  Step 1: Key points from the article include:\n...
# 5  Step 1: Identify key points\n- Trey Moses, a h...
# 6  The Amnesty International annual report on the...
# 7  Andrew Getty, grandson of oil magnate J. Paul ...
# 8  Step 1: Identify key points\n- Tropical storm ...
# 9  Error: Hugging Face request failed: Client err...
#
#                                       vicuna_summary  \
# 0  The Palestinian Authority officially became th...
# 1  A stray dog in Washington State survived being...
# 2  Mohammad Javad Zarif, the Iranian foreign mini...
# 3  Five Americans who were exposed to Ebola in Si...
# 4  A Duke student was identified for hanging a no...
# 5  Trey Moses, a blue chip college basketball rec...
# 6  Governments around the world are using the thr...
# 7  Andrew Getty, one of the heirs to the Getty fa...
# 8  Tropical storm Maysak is approaching the Phili...
# 9  For the first time in eight years, TV legend B...
#
#                                          id  \
# 0  f001ec5c4704938247d27a44948eebb37ae98d01
# 1  230c522854991d053fe98a718b1defa077a8efef
# 2  4495ba8f3a340d97a9df1476f8a35502bcce1f69
# 3  a38e72fed88684ec8d60dd5856282e999dc8c0ca
# 4  c27cf1b136cc270023de959e7ab24638021bc43f
# 5  1b2cc634e2bfc6f2595260e7ed9b42f77ecbb0ce
# 6  e2706dce6cf26bc61b082438188fdb6e130d9e40
# 7  0d3c8c276d079c4c225f034c69aa024cdab7869d
# 8  6222f33c2c79b80be437335eeb3f488509e92cf5
# 9  2bd8ada1de6a7b02f59430cc82045eb8d29cf033
#
#                                              article  \
# 0  (CNN)The Palestinian Authority officially beca...
# 1  (CNN)Never mind cats having nine lives. A stra...
# 2  (CNN)If you've been following the news lately,...
# 3  (CNN)Five Americans who were monitored for thr...
# 4  (CNN)A Duke student has admitted to hanging a ...
# 5  (CNN)He's a blue chip college basketball recru...
# 6  (CNN)Governments around the world are using th...
# 7  (CNN)Andrew Getty, one of the heirs to billion...
# 8  (CNN)Filipinos are being warned to be on guard...
# 9  (CNN)For the first time in eight years, a TV l...
#
#                                              summary
# 0  Membership gives the ICC jurisdiction over all...
# 1  Theia, a bully breed mix, was apparently hit b...
# 2  Mohammad Javad Zarif has spent more time with ...
# 3  17 Americans were exposed to the Ebola virus w...
# 4  Student is no longer on Duke University campus...
# 5  College-bound basketball star asks girl with D...
# 6  Amnesty's annual death penalty report catalogs...
# 7  Andrew Getty's death appears to be from natura...
# 8  Once a super typhoon, Maysak is now a tropical...
# 9  Bob Barker returned to host "The Price Is Righ...

# %%
final_df.to_csv("CNN_cot.csv", index=False)
